# %%
"""
School of Information Technology 

STUDENT'S SCORES AND REPORTING SYSTEM

Submitted in the Fulfillment of the requirements for Bachelor of  Business Information Systems

Computational Thinking and Introduction to Programming  
Course Code: SEN152
Assessment Code: SS3

Student no. : 26303339
Mamasegare Angello Tshoga


#--------- Introduction --------
A program that shows student's marks in a data set, allowing the user to:
1. Search a student in the data set using the student's idea.
2. Add a new student.
3. Delete the records of a student using the student's ID.
4. Identify top and low performers.
5. View class statistics: averages, passrate etc.
6. View the class report. 

    *** All inputs undergo validation with appropriate error handling and error messages for correction. ***
    

"""

#5.STUDENTS DATA SET
students = {
"ST001": {
    "name": "Alice Smith",
    "scores": [88, 91, 84]
},
"ST002": {
    "name": "Brian Adams",
    "scores": [65, 72, 68]
},
"ST003": {
    "name": "Carla Jones",
    "scores": [45, 52, 49]
},
"ST004": {
    "name": "David Brown",
    "scores": [95, 90, 93]
},
"ST005": {
    "name": "Emma White",
    "scores": [55, 61, 58]
},
"ST006": {
    "name": "Frank Daniels",
    "scores": [32, 40, 35]
},
"ST007": {
    "name": "Grace Lee",
    "scores": [78, 81, 79]
},
"ST008": {
    "name": "Henry Miller",
    "scores": [69, 71, 70]
},
"ST009": {
    "name": "Ivy Green",
    "scores": [82, 88, 85]
},
"ST010": {
    "name": "Jack Wilson",
    "scores": [48, 51, 47]
}}


#6. FUNCTIONS 
"""
addStudent()
    verifyStudentID()
search_student()
calculate_average()
class_average()
display_report()
delete_student()
addStudent()
exit
"""


#7. TASKS
#-------Add a student -------

def addStudent():
    print ("\n /////  ///// ///// ///// /////")
    print("\n ///// Add a student/////")
    print ("\n /////  ///// ///// ///// /////")

    #empty variable for loops (student ID, name and scores to access it and attache the corresponding values)
    savedID = None
    
    #---------Validate student ID ---------
    while True:
        #Request student's details
        studentDetailID = input("What's the student's ID (example: ST079)?")

        #Create validation condition
        if verifyStudentID(studentDetailID):
            try:
                
                #if verified using the results of the input field, then print to students list.
                students[studentDetailID]={}
                savedID = studentDetailID #Saved to be used in the next loop.
                print("*"*15)
                print("Student ID added successfully", {studentDetailID})
                print("*"*15)
                break
            except Exception as e:
                print (f"Error adding student ID {e}")
            break #Exit loop when a student ID is successfully validated and added.

        else:
            print("Invalid, please try again.")
            
     #---------Validate student Name ---------
    while True:
        studentDetailName = input("What's the student's name?")
    

        #Validate input field (student name and family name).
        if len(studentDetailName)>= 2 and " " in studentDetailName:
            
            #save the student name to the specific student ID (saved ID) 
            students[savedID]["name"]=studentDetailName   #add the input to the name key 
            
            print("Student name and family name successfully added")
            print("*"*15)
            print("New student name and family name:", students) #add to main dictionary
            print("*"*15)
            break
        else: 
            print("Invalid. Enter student's name and family name.")
            
    while True:
        studentDetailScores = int(input("What's the student's scores (example: 55)?"))
        
        try:
        #Validate scores input field
            if 0 <= studentDetailScores <= 100:
            
                #save the student's scores to the specific student ID (saved ID)
                students[savedID]["scores"] = studentDetailScores
                print("Student's scores, successfully added")
                print("*"*15)
                print(f"New student's scores successfully added:{studentDetailName}", students)
                print("*"*15)
                break
            else:
                print("Invalid. Enter student's score.")
                
            #Catch any errors like letters and characters that may be input to prevent crashing.
        except valueError:
            print("Invalid input. Please input a number.")
            

       
def verifyStudentID(studentInfo):
    hasUpper = any (char.isupper() for char in studentInfo)
    hasDigit = any (char.isdigit() for char in studentInfo)
    hasLength = len(studentInfo) >= 5

        #if all verification requirements are met.
    if hasUpper and hasDigit and hasLength:
        return True
            
        #if verification requirements are not met    
    if not hasUpper:
        print("Invalid. Follow format of student ID (example: ST)")

    if not hasDigit:
        print("Invalid. Follow format of student ID (example: 001)")
    if not hasLength:
        print("Length of the student ID is atleast 5 digits.")
    return False
#addStudent()  #just to test block of code



"""

def allStudents():
    print ("\n /////  ///// ///// ///// /////")
    print("\n ///// List of all students /////")
    print ("\n /////  ///// ///// ///// /////")
    
    for x in students:
        print(students[x])

    print("\n ///// Next /////")
    print("What do you want to do?")
    print("1. Search and see a student's marks.")
    print("2. Calculate averages.")
    print("3. Delete records.")
    
    nextChoice = input("Choose a number (1 - 3)")
    
    if nextChoice == "1":
         search_student()
    #elif nextChoice == "2":
         #averages()
    #elif nextChoice == "3":
          #deleteRecords()
allStudents()
"""
#-------- Search for a student ------
#look for student using the user's input
def search_student(): 
    #Request student number to search for student
    print ("\n /////  ///// ///// ///// /////")
    print("\n ///// Search for student/////")
    print ("\n /////  ///// ///// ///// /////")
    requestStudent = input("Search for a student using student ID")
    if requestStudent in students:
        print("Student is:", students[requestStudent])
    
    else:
        print("Student not found, seach for a studet using their student ID.")
   

        #--------2nd attempt----------
        #look for student using the user's input (2nd attempt)
        requestStudent = input("Please try again. Search for a student using student ID")
    
        if requestStudent in students:
            print("*"*10)
            print("Student is:", students[requestStudent])
            print("*"*10)
        else:
            print("Student not found. Exiting search")


#--------Calculate averages -------
def calculate_average():
    print ("\n /////  ///// ///// ///// /////")
    print("\n ///// Student's average /////")
    print ("\n /////  ///// ///// ///// /////")


    #create empty buckets to group students
    distinction_students = []
    pass_students = []
    fail_students = []

    #Thresholds that the 1st student's average score will compared against. 
    highestAverage = 0
    lowestAverage = 101

    #Thresholds for class average logic
    totalSum = 0
    count = 0
    totalStudents = 0

    #Threshold for passrate 
    studentPass = 0
    studentFail = 0

    print(f"{'ID':<10}{'NAME':<18}{'SCORES':<18}{'AVERAGE':<18}{'STATUS':<18}")

    
    for x in students: #Loop 1: Go through every student ID
        
        #Count each student
        totalStudents += 1
        
        #get student and scores from the list of students
        students_scores = students [x]["scores"]
        student_name = students [x] ["name"]

        average_score = round(sum(students_scores) / len(students_scores), 2) #use round() to round the decimal places t0 2.

        #change list of numbers to one string otherwise format error for the table format
        changeScores = ", ".join(map(str, students_scores))
        
        #------Track highest performer -------
        #Loop 2: Go through each individual mark, to track top performer 
        #If the first student in the loop is higher than the highest average (0) then the new first student's average will be the new threshold from which the loop will compare the new student.
        if average_score > highestAverage:
            highestAverage = average_score
            highestStudent = student_name

        #------Track lowest performer-----
        #If the first student in the loop is lower than the lowest average (101, as these are % therefore out of 100%) then the new first student's average will be the new threshold from which the loop will compare the new student.
        #student 1 with average of x will replace lowest average (101) then student two will be compared with student ones mark, if lower, then student 2 becomes new threshold.

        elif average_score < lowestAverage:
            lowestAverage = average_score
            lowestStudent = student_name
            
        else: 
            print("")

        

            
        #Print the results 
        if average_score >= 75:
           #print(f"{student_name} (ID: {x}) | Average: {average_score} | Distinction")
           print(f"{x:<10}{student_name:<18}{changeScores:<18}{average_score:<18}Distinction")
           studentPass += 1 #count this student as having passed
           passName = student_name #store that student that passed's name.
           pass_students.append(student_name) #append is used to add student's names to the empty list: pass_students = []         
           
        elif average_score >= 50:
            #print(f"{student_name} (ID: {x}) | Average: {average_score} | Pass")
            print(f"{x:<10}{student_name:<18}{changeScores:<18}{average_score:<18}Pass")
            studentPass += 1 #count this student as having passed
            passName = student_name #store that student that passed's name.
            pass_students.append(student_name) #append is used to add student's names to the empty list: pass_students = []
        
        else:
            #print(f"{student_name} (ID: {x}) | Average: {average_score} | Fail")
            print(f"{x:<10}{student_name:<18}{changeScores:<18}{average_score:<18}Fail")
            studentFail += 1 #count this student as having failed
            failName = student_name #store the student that failed's name
            fail_students.append(student_name) #append is used to add student's names to the empty list: fail_students = []
        


#------ Class statistics-------
        for score in students_scores: #each score in the student's records
            totalSum = totalSum + score 
            count = count + 1
    #calculate the average after the loops
    if count > 0:
        total_average = round ((totalSum / count), 2)
            
#------ Pass Rate -----
        
    if totalStudents > 0:
        passRate = round ((studentPass / totalStudents)*100, 2 )
    else:
        passRate = 0
        
#------ List of student's that passed and failed
    print("\n ----- Students that passed-----") 
    studentsPassed = "\n".join(pass_students)
    print(studentsPassed)

    print("\n ----- Students that failed-----") 
    studentsFailed = "\n".join(fail_students)
    print(studentsFailed)

            
    print ("\n /////  ///// ///// ///// /////")
    print("\n ///// Student's statistics //////")
    print ("\n /////  ///// ///// ///// /////")

    print ("\n ----- Top Performer -----")
    print(f" The top performer is {highestStudent} with an average of {highestAverage}")

    print("\n ----- Lowest Performer -----")
    print(f"The lowest performer is {lowestStudent} with an average of {lowestAverage}")

    print("\n ----- Class average -----")
    print(f"The class average is", total_average)

    print("\n ----- Pass Rate -----") 
    print(f"The passrate is: {passRate}")
    
    


#--------Calculate class average --------
        
def class_average():
    totalSum = 0
    count = 0
    
    print ("\n /////  ///// ///// ///// /////")
    print ("\n ///// Class average /////")
    print ("\n /////  ///// ///// ///// /////")
    for x in students: #Loop 1: Go through every student ID
    #Grab student's scores
        students_scores = students [x] ["scores"]

        #Loop 2: Go through each individual mark 
        for score in students_scores:
            totalSum = totalSum + score
            count = count + 1
    #calculate the average after the loops
    if count > 0:
        total_average = round (totalSum / count, 2)

    print("The class average is", total_average) 


#---------- Class report --------------

def display_report():

    print ("-"*(10+18*3+10)) #10+18*3+10 = length of columns combined
    print ("\n Student Performance Report")
    print ("-"*(10+18*3+10))

    print(f"{'ID':<10}{'NAME':<18}{'SCORES':<18}{'AVERAGE':<18}{'STATUS':<18}")

    for x in students:
        #get student and scores from the list of students
        student_name = students [x] ["name"]
        students_scores = students [x]["scores"]

        average_score = round(sum(students_scores) / len(students_scores), 2)

        #change list of numbers to one string otherwise format error
        changeScores = ", ".join(map(str, students_scores))

        if average_score >= 75:
            print(f"{x:<10}{student_name:<18}{changeScores:<18}{average_score:<18}Distinction")

        elif average_score >= 50:
            print(f"{x:<10}{student_name:<18}{changeScores:<18}{average_score:<18}Pass")

        else:
            print(f"{x:<10}{student_name:<18}{changeScores:<18}{average_score:<18}Fail")
    
    
    print("-"*(10+18*3+10))


#------------- Delete student -------------
def delete_student():
    print ("\n /////  ///// ///// ///// /////")
    print ("\n ///// Delete a student /////")
    print ("\n /////  ///// ///// ///// /////")

    studentDelete = input("Enter student ID you would like to delete?")

    if studentDelete in students:
        del students [studentDelete]
        print("*"*10)
        print(f"Student ID {studentDelete} deleted")
        print("*"*10)
    
    else:
        print("Invalid. \n Enter student ID you would like to delete (example: ST001)")
        studentDelete = input("Enter student ID you would like to delete?")

        if studentDelete in students:
            del students [studentDelete]
            print("*"*10)
            print(f"Student ID {studentDelete} deleted")
            print("*"*10)
        else:
                print("Invalid student ID.")
 

#--------Home Menu -------
#2. Create home menu items

def homeMenu():
    while True: #to keep menu running 
        print ("="*60)
        print("\n What do you want to do?")
        print ("="*60)
    
        print("1. Search and see a student's marks.")
        print("2. Averages and class statistics")
        print("3. Student Report")
        print("4. Delete records")
        print("5. Add a student")
        print("6. Exit")
    
        menuChoice = input("Choose a number (1 - 6)")
    

        if menuChoice == "1":
            search_student()
        elif menuChoice == "2":
            calculate_average()
        elif menuChoice == "3":
            display_report()
        elif menuChoice == "4":
            delete_student()
        elif menuChoice == "5":
            addStudent()
            
        elif menuChoice == "6":
           print("\n ///// exiting /////")
           print("\n")
homeMenu()



#9. FINAL OUTPUT
"""

 *** These are inputs that the user would make. 
 --------------------------------------------------------
 
============================================================

 What do you want to do?
============================================================
1. Search and see a student's marks.
2. Averages and class statistics
3. Student Report
4. Delete records
5. Add a student
6. Exit
Choose a number (1 - 6) 1            ***

/////  ///// ///// ///// /////

 ///// Search for student/////

 /////  ///// ///// ///// /////
Search for a student using student ID:  STD01 ***


Student not found, seach for a studet using their student ID.
Please try again. Search for a student using student ID: ST001  ***

**********
Student is: {'name': 'Ivy Green', 'scores': [82, 88, 85]}
**********


============================================================

 What do you want to do?
============================================================
1. Search and see a student's marks.
2. Averages and class statistics
3. Student Report
4. Delete records
5. Add a student
6. Exit
Choose a number (1 - 6): 2    ***

/////  ///// ///// ///// /////

 ///// Student's average /////

 /////  ///// ///// ///// /////
ID        NAME              SCORES            AVERAGE           STATUS            
ST001     Alice Smith       88, 91, 84        87.67             Distinction
ST002     Brian Adams       65, 72, 68        68.33             Pass
ST003     Carla Jones       45, 52, 49        48.67             Fail
ST004     David Brown       95, 90, 93        92.67             Distinction
ST005     Emma White        55, 61, 58        58.0              Pass
ST006     Frank Daniels     32, 40, 35        35.67             Fail
ST007     Grace Lee         78, 81, 79        79.33             Distinction
ST008     Henry Miller      69, 71, 70        70.0              Pass
ST009     Ivy Green         82, 88, 85        85.0              Distinction
ST010     Jack Wilson       48, 51, 47        48.67             Fail


 ----- Students that passed-----
Alice Smith
Brian Adams
David Brown
Emma White
Grace Lee
Henry Miller
Ivy Green

 ----- Students that failed-----
Carla Jones
Frank Daniels
Jack Wilson

 /////  ///// ///// ///// /////

 ///// Student's statistics //////

 /////  ///// ///// ///// /////

 ----- Top Performer -----
 The top performer is David Brown with an average of 92.67

 ----- Lowest Performer -----
The lowest performer is Frank Daniels with an average of 35.67

 ----- Class average -----
The class average is 69.48

 ----- Pass Rate -----
The passrate is: 77.78
============================================================

 What do you want to do?
============================================================
1. Search and see a student's marks.
2. Averages and class statistics
3. Student Report
4. Delete records
5. Add a student
6. Exit
Choose a number (1 - 6) 3      ***

--------------------------------------------------------------------------

 Student Performance Report
--------------------------------------------------------------------------
ID        NAME              SCORES            AVERAGE           STATUS            
ST001     Alice Smith       88, 91, 84        87.67             Distinction
ST002     Brian Adams       65, 72, 68        68.33             Pass
ST003     Carla Jones       45, 52, 49        48.67             Fail
ST004     David Brown       95, 90, 93        92.67             Distinction
ST005     Emma White        55, 61, 58        58.0              Pass
ST006     Frank Daniels     32, 40, 35        35.67             Fail
ST007     Grace Lee         78, 81, 79        79.33             Distinction
ST008     Henry Miller      69, 71, 70        70.0              Pass
ST009     Ivy Green         82, 88, 85        85.0              Distinction
ST010     Jack Wilson       48, 51, 47        48.67             Fail
--------------------------------------------------------------------------
============================================================

 What do you want to do?
============================================================
1. Search and see a student's marks.
2. Averages and class statistics
3. Student Report
4. Delete records
5. Add a student
6. Exit
Choose a number (1 - 6)   4


/////  ///// ///// ///// /////

 ///// Delete a student /////

 /////  ///// ///// ///// /////
Enter student ID you would like to delete?  ST0    ***

Invalid. 
 Enter student ID you would like to delete (example: ST001)
Enter student ID you would like to delete?  ST008

**********
Student ID ST008 deleted
**********

============================================================

 What do you want to do?
============================================================
1. Search and see a student's marks.
2. Averages and class statistics
3. Student Report
4. Delete records
5. Add a student
6. Exit
Choose a number (1 - 6) 5

/////  ///// ///// ///// /////

 ///// Add a student/////

 /////  ///// ///// ///// /////
What's the student's ID (example: ST079)? ST01     ***

Length of the student ID is atleast 5 digits.
Invalid, please try again.
What's the student's ID (example: ST079)? 

Invalid. Follow format of student ID (example: 001)
Length of the student ID is atleast 5 digits.
Invalid, please try again.
What's the student's ID (example: ST079)?  ST012    ***

***************
Student ID added successfully {'ST012'}
***************
What's the student's name? n    ***

Invalid. Enter student's name and family name.
What's the student's name? c a      ***

Student name and family name successfully added
***************
New student name and family name: {'ST001': {'name': 'Alice Smith', 'scores': [88, 91, 84]}, 'ST002': {'name': 'Brian Adams', 'scores': [65, 72, 68]}, 'ST003': {'name': 'Carla Jones', 'scores': [45, 52, 49]}, 'ST004': {'name': 'David Brown', 'scores': [95, 90, 93]}, 'ST005': {'name': 'Emma White', 'scores': [55, 61, 58]}, 'ST006': {'name': 'Frank Daniels', 'scores': [32, 40, 35]}, 'ST007': {'name': 'Grace Lee', 'scores': [78, 81, 79]}, 'ST009': {'name': 'Ivy Green', 'scores': [82, 88, 85]}, 'ST012': {'name': 'c '}}
***************

What's the student's scores (example: 55)? 15

Student's scores, successfully added
***************
New student's scores successfully added:c a {'ST001': {'name': 'Alice Smith', 'scores': [88, 91, 84]}, 'ST002': {'name': 'Brian Adams', 'scores': [65, 72, 68]}, 'ST003': {'name': 'Carla Jones', 'scores': [45, 52, 49]}, 'ST004': {'name': 'David Brown', 'scores': [95, 90, 93]}, 'ST005': {'name': 'Emma White', 'scores': [55, 61, 58]}, 'ST006': {'name': 'Frank Daniels', 'scores': [32, 40, 35]}, 'ST007': {'name': 'Grace Lee', 'scores': [78, 81, 79]}, 'ST008': {'name': 'Henry Miller', 'scores': [69, 71, 70]}, 'ST009': {'name': 'Ivy Green', 'scores': [82, 88, 85]}, 'ST010': {'name': 'Jack Wilson', 'scores': [48, 51, 47]}, 'ST012': {'name': 'c a', 'scores': 15}}
***************

"""

#------- Conclusion -----
#All errors are handled in the program with the functions functioning as intended and return valid outputs.
# Out:
# ...
#
#  What do you want to do?
# ...
# 1. Search and see a student's marks.
# 2. Averages and class statistics
# 3. Student Report
# 4. Delete records
# 5. Add a student
# 6. Exit
# Choose a number (1 - 6) 1
#  /////  ///// ///// ///// /////
#
#  ///// Search for student/////
#
#  /////  ///// ///// ///// /////
# Search for a student using student ID ST010
# Student is: {'name': 'Jack Wilson', 'scores': [48, 51, 47]}
# ...
#
#  What do you want to do?
# ...
# 1. Search and see a student's marks.
# 2. Averages and class statistics
# 3. Student Report
# 4. Delete records
# 5. Add a student
# 6. Exit
# Choose a number (1 - 6) 2
#  /////  ///// ///// ///// /////
#
#  ///// Student's average /////
#
#  /////  ///// ///// ///// /////
# ID        NAME              SCORES            AVERAGE           STATUS
# ST001     Alice Smith       88, 91, 84        87.67             Distinction
# ST002     Brian Adams       65, 72, 68        68.33             Pass
# ...
